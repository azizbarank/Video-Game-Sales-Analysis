# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/content/vgsales.csv')

# %%
df.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
df.dropna(subset= ["Year"], inplace=True)

# %%
df.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
df['Year'] = df['Year'].astype(int)
df['Year'] = pd.to_datetime(df['Year'], format='%Y')
df['Year'].head()
# Out:
# 0   2006-01-01
# 1   1985-01-01
# 2   2008-01-01
# 3   2009-01-01
# 4   1996-01-01
# Name: Year, dtype: datetime64[ns]

# %%
df.head()
# Out:
#    Rank                      Name Platform       Year         Genre Publisher  \
# 0     1                Wii Sports      Wii 2006-01-01        Sports  Nintendo
# 1     2         Super Mario Bros.      NES 1985-01-01      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii 2008-01-01        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii 2009-01-01        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB 1996-01-01  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16327 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16327 non-null  int64
#  1   Name          16327 non-null  object
#  2   Platform      16327 non-null  object
#  3   Year          16327 non-null  datetime64[ns]
#  4   Genre         16327 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16327 non-null  float64
#  7   EU_Sales      16327 non-null  float64
#  8   JP_Sales      16327 non-null  float64
#  9   Other_Sales   16327 non-null  float64
#  10  Global_Sales  16327 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
df.nunique()
# Out:
# Rank            16327
# Name            11360
# Platform           31
# Year               39
# Genre              12
# Publisher         576
# NA_Sales          408
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      621
# dtype: int64

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Action          3253
# Sports          2304
# Misc            1710
# Role-Playing    1471
# Shooter         1282
# Adventure       1276
# Racing          1226
# Platform         876
# Simulation       851
# Fighting         836
# Strategy         671
# Puzzle           571
# Name: count, dtype: int64

# %%
df['Platform'].value_counts()
# Out:
# Platform
# DS      2133
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1235
# PSP     1197
# PS      1189
# PC       943
# GBA      811
# XB       803
# GC       542
# 3DS      500
# PSV      412
# PS4      336
# N64      316
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     116
# NES       98
# GB        97
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: count, dtype: int64

# %%
df['Publisher'].value_counts().head(30)
# Out:
# Publisher
# Electronic Arts                           1339
# Activision                                 966
# Namco Bandai Games                         928
# Ubisoft                                    918
# Konami Digital Entertainment               823
# THQ                                        712
# Nintendo                                   696
# Sony Computer Entertainment                682
# Sega                                       632
# Take-Two Interactive                       412
# Capcom                                     376
# Atari                                      347
# Tecmo Koei                                 338
# Square Enix                                231
# Warner Bros. Interactive Entertainment     217
# Disney Interactive Studios                 214
# Midway Games                               196
# Eidos Interactive                          196
# 505 Games                                  192
# Microsoft Game Studios                     189
# ...

# %%
publisher_global_sales = df.groupby('Publisher')['Global_Sales'].sum()
publisher_global_sales.sort_values(ascending=False).head(20)
# Out:
# Publisher
# Nintendo                                  1784.43
# Electronic Arts                           1093.39
# Activision                                 721.41
# Sony Computer Entertainment                607.28
# Ubisoft                                    473.54
# Take-Two Interactive                       399.30
# THQ                                        340.44
# Konami Digital Entertainment               278.56
# Sega                                       270.70
# Namco Bandai Games                         253.65
# Microsoft Game Studios                     245.79
# Capcom                                     199.95
# Atari                                      146.77
# Square Enix                                144.73
# Warner Bros. Interactive Entertainment     142.34
# Disney Interactive Studios                 118.76
# Eidos Interactive                           96.75
# LucasArts                                   84.95
# Bethesda Softworks                          81.53
# ...

# %%
publisher_na_sales = df.groupby('Publisher')['NA_Sales'].sum()
publisher_na_sales.sort_values(ascending=False).head(20)
# Out:
# Publisher
# Nintendo                                  815.75
# Electronic Arts                           584.22
# Activision                                426.01
# Sony Computer Entertainment               265.22
# Ubisoft                                   252.81
# Take-Two Interactive                      220.47
# THQ                                       208.60
# Microsoft Game Studios                    155.35
# Sega                                      108.78
# Atari                                     101.23
# Konami Digital Entertainment               88.91
# Capcom                                     78.45
# Warner Bros. Interactive Entertainment     75.34
# Disney Interactive Studios                 70.44
# Namco Bandai Games                         69.38
# Square Enix                                48.59
# LucasArts                                  48.43
# Eidos Interactive                          47.85
# Midway Games                               45.10
# ...

# %%
publisher_eu_sales = df.groupby('Publisher')['EU_Sales'].sum()
publisher_eu_sales.sort_values(ascending=False).head(20)
# Out:
# Publisher
# Nintendo                                  418.30
# Electronic Arts                           367.38
# Activision                                213.72
# Sony Computer Entertainment               187.55
# Ubisoft                                   163.03
# Take-Two Interactive                      117.95
# THQ                                        94.60
# Sega                                       81.41
# Konami Digital Entertainment               68.62
# Microsoft Game Studios                     68.61
# Warner Bros. Interactive Entertainment     48.83
# Namco Bandai Games                         42.61
# Capcom                                     39.16
# Eidos Interactive                          34.85
# Disney Interactive Studios                 34.36
# Square Enix                                32.57
# Bethesda Softworks                         30.48
# Codemasters                                28.65
# LucasArts                                  26.00
# ...

# %%
publisher_jp_sales = df.groupby('Publisher')['JP_Sales'].sum()
publisher_jp_sales.sort_values(ascending=False).head(20)
# Out:
# Publisher
# Nintendo                        454.99
# Namco Bandai Games              126.84
# Konami Digital Entertainment     90.93
# Sony Computer Entertainment      74.10
# Capcom                           67.38
# Sega                             56.19
# Square Enix                      49.79
# SquareSoft                       40.13
# Enix Corporation                 32.40
# Tecmo Koei                       29.21
# Hudson Soft                      19.21
# Banpresto                        16.44
# Electronic Arts                  13.98
# Level 5                          11.65
# Atari                            10.70
# ASCII Entertainment               9.40
# Virgin Interactive                8.94
# Ubisoft                           7.33
# Atlus                             6.73
# Activision                        6.54
# Name: JP_Sales, dtype: float64

# %%
platform_global_sales = df.groupby('Platform')['Global_Sales'].sum()
platform_global_sales.sort_values(ascending=False)
# Out:
# Platform
# PS2     1233.46
# X360     969.61
# PS3      949.35
# Wii      909.81
# DS       818.96
# PS       727.39
# GBA      313.56
# PSP      291.71
# PS4      278.10
# PC       255.05
# GB       254.42
# XB       252.09
# NES      251.07
# 3DS      246.28
# N64      218.21
# SNES     200.05
# GC       197.14
# XOne     141.06
# 2600      86.57
# WiiU      81.86
# PSV       61.63
# SAT       33.59
# GEN       28.36
# DC        15.97
# SCD        1.87
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: Global_Sales, dtype: float64

# %%
platform_na_sales = df.groupby('Platform')['NA_Sales'].sum()
platform_na_sales.sort_values(ascending=False)
# Out:
# Platform
# X360    594.33
# PS2     572.92
# Wii     497.37
# PS3     388.90
# DS      388.56
# PS      334.71
# GBA     184.12
# XB      182.06
# N64     138.91
# GC      131.94
# NES     125.94
# GB      113.64
# PSP     107.09
# PS4      96.80
# PC       92.10
# XOne     83.19
# 2600     80.78
# 3DS      78.03
# SNES     61.23
# WiiU     38.32
# GEN      19.27
# PSV      16.07
# DC        5.43
# SCD       1.00
# SAT       0.72
# 3DO       0.00
# PCFX      0.00
# NG        0.00
# GG        0.00
# TG16      0.00
# WS        0.00
# Name: NA_Sales, dtype: float64

# %%
platform_eu_sales = df.groupby('Platform')['EU_Sales'].sum()
platform_eu_sales.sort_values(ascending=False)
# Out:
# Platform
# PS3     340.47
# PS2     332.63
# X360    278.01
# Wii     264.35
# PS      212.38
# DS      194.07
# PC      137.64
# PS4     123.70
# GBA      74.59
# PSP      67.16
# XB       59.65
# 3DS      58.30
# GB       47.51
# XOne     45.65
# N64      41.03
# GC       38.32
# WiiU     24.23
# NES      21.15
# SNES     19.04
# PSV      16.27
# GEN       5.52
# 2600      4.86
# DC        1.69
# SAT       0.54
# SCD       0.36
# WS        0.00
# TG16      0.00
# 3DO       0.00
# GG        0.00
# NG        0.00
# PCFX      0.00
# Name: EU_Sales, dtype: float64

# %%
platform_jp_sales = df.groupby('Platform')['JP_Sales'].sum()
platform_jp_sales.sort_values(ascending=False)
# Out:
# Platform
# DS      175.02
# PS      139.78
# PS2     137.54
# SNES    116.55
# NES      98.65
# 3DS      97.30
# GB       85.12
# PS3      79.21
# PSP      75.89
# Wii      68.28
# GBA      46.56
# N64      33.76
# SAT      32.26
# GC       21.34
# PSV      20.89
# PS4      14.30
# WiiU     12.79
# X360     12.30
# DC        8.56
# GEN       2.67
# NG        1.44
# WS        1.42
# XB        1.38
# SCD       0.45
# XOne      0.34
# PC        0.17
# TG16      0.16
# 3DO       0.10
# GG        0.04
# PCFX      0.03
# 2600      0.00
# Name: JP_Sales, dtype: float64

# %%
genre_global_sales = pd.DataFrame(df.groupby('Genre')['Global_Sales'].sum()).sort_values('Global_Sales', ascending=False)
genre_global_sales
# Out:
#               Global_Sales
# Genre
# Action             1722.88
# Sports             1309.24
# Shooter            1026.20
# Role-Playing        923.84
# Platform            829.15
# Misc                797.62
# Racing              726.77
# Fighting            444.05
# Simulation          390.16
# Puzzle              242.22
# Adventure           234.80
# Strategy            173.43

# %%
genre_global_sales['Global_Sales'].plot.pie(title= 'Global Game Sales Per Genre in %', autopct = '%1.1f', figsize=(10,10))
# Out:
# <Axes: title={'center': 'Global Game Sales Per Genre in %'}, ylabel='Global_Sales'>

# %%
genre_global_sales_2 = pd.DataFrame(df.groupby('Genre')['Global_Sales'].sum()).sort_values('Global_Sales', ascending=True)
genre_global_sales_2.plot.barh(title= 'Global Game Sales Per Genre', color = 'DarkBlue', figsize=(10,9))
# Out:
# <Axes: title={'center': 'Global Game Sales Per Genre'}, ylabel='Genre'>

# %%
genre_na_sales = pd.DataFrame(df.groupby('Genre')['NA_Sales'].sum()).sort_values('NA_Sales', ascending=False)

# %%
genre_na_sales['NA_Sales'].plot.pie(title= 'Game Sales Per Genre in North America in %', autopct = '%1.1f', figsize=(10,10))
# Out:
# <Axes: title={'center': 'Game Sales Per Genre in North America in %'}, ylabel='NA_Sales'>

# %%
genre_eu_sales = pd.DataFrame(df.groupby('Genre')['EU_Sales'].sum()).sort_values('EU_Sales', ascending=False)

# %%
genre_eu_sales['EU_Sales'].plot.pie(title= 'Game Sales Per Genre in EU in %', autopct = '%1.1f', figsize=(10,10))
# Out:
# <Axes: title={'center': 'Game Sales Per Genre in EU in %'}, ylabel='EU_Sales'>

# %%
genre_jp_sales = pd.DataFrame(df.groupby('Genre')['JP_Sales'].sum()).sort_values('JP_Sales', ascending=False)

# %%
genre_jp_sales['JP_Sales'].plot.pie(title= 'Game Sales Per Genre in Japan in %', autopct = '%1.1f', figsize=(10,10))
# Out:
# <Axes: title={'center': 'Game Sales Per Genre in Japan in %'}, ylabel='JP_Sales'>

# %%
df.set_index('Year', inplace=True)
df.head()
# Out:
#             Rank                      Name Platform         Genre Publisher  \
# Year
# 2006-01-01     1                Wii Sports      Wii        Sports  Nintendo
# 1985-01-01     2         Super Mario Bros.      NES      Platform  Nintendo
# 2008-01-01     3            Mario Kart Wii      Wii        Racing  Nintendo
# 2009-01-01     4         Wii Sports Resort      Wii        Sports  Nintendo
# 1996-01-01     5  Pokemon Red/Pokemon Blue       GB  Role-Playing  Nintendo
#
#             NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year
# 2006-01-01     41.49     29.02      3.77         8.46         82.74
# 1985-01-01     29.08      3.58      6.81         0.77         40.24
# 2008-01-01     15.85     12.88      3.79         3.31         35.82
# 2009-01-01     15.75     11.01      3.28         2.96         33.00
# 1996-01-01     11.27      8.89     10.22         1.00         31.37

# %%
yearly_counts = df.resample('Y').count()

# %%
plt.plot(yearly_counts.index, yearly_counts['Genre'])
plt.xlabel('Year')
plt.ylabel('Count of Genre')
plt.title('The Count of Genre Sales through Years')
plt.show()

# %%
genre = df.groupby('Genre').resample('Y').size().unstack(level=0)

# %%
genre.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Year'>

# %%
top_15_platforms = df['Platform'].value_counts().head(15).index
platform = df[df['Platform'].isin(top_15_platforms)].groupby('Platform').resample('Y').size().unstack(level=0)
platform.plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Year'>

# %%
top_10_publisher = df['Publisher'].value_counts().head(10).index
platform = df[df['Publisher'].isin(top_10_publisher)].groupby('Publisher').resample('Y').size().unstack(level=0)
platform.plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Year'>

# %%
df.to_csv('games_analysis_cleaned.csv')
